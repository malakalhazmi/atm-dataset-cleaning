# %%
import pandas as pd
import re

# %%
atm_original = pd.read_excel(r' HERE THE PATH TO THE DATASET GOES ', sep = '\t')
atm = atm_original.copy()

# %%
class Filter():
    
    def clean_x_y_coordinates(self, coordinate):
        '''
     (5): Both 'Y GIS Coordinates' & 'X GIS Coordinates' are full of things that should be cleand out 
          before using them (i.e. render them as markers on goolge map)
        
        '''
  # If coordinate is String means there is something that should be cleand 
        if isinstance(coordinate,str):
            temp_list = list(coordinate)
        
        # 1:'Militaryzone' is a value that means (this location is confidential)
            if coordinate == 'Militaryzone':
                return '0'
            
        # 2:',' is meaningless
            elif ',' in coordinate:
                return coordinate.replace(',','')
            
        # 3:'°' it means when it comes in the end of coordinate dd or 'Decimal Degrees'
            elif coordinate[-1] == '°' :
                return coordinate.replace('°','')
            
        # 4:when 'E' or 'N' comes in the biggingn of coordinate with no other symbols..
        #   we can't convert dms 'Degrees,Minutes,Seconds' to dd
            elif (coordinate[0] == 'E' or coordinate[0] == 'N'):    
                return '0'
            
        # 5:when 'E' or 'N' comes in the end of coordinate without ° & ' symbols..
        #   we can't convert dms 'Degrees,Minutes,Seconds' to dd
        #   just get raid of this extra N or E
            elif  ('°' and "'" not in coordinate) and (coordinate[-1] == 'E' or coordinate[-1] == 'N'):
                if 'N' in coordinate:
                    return coordinate.replace('N','')
                elif 'E' in coordinate:
                    return coordinate.replace('E','')
                
        # 6:when 'E' or 'N' comes in the end of coordinate with ° & ' symbols..
        #   we can convert dms 'Degrees,Minutes,Seconds' to dd
            elif  ('°' and "'" and 'N' in coordinate) or ('°' and "'" and 'E' in coordinate):
                print(coordinate)
                degrees, minutes, direction = re.split('[°\']+', coordinate)
                dd = float(degrees) + float(minutes)/60 ;
                return dd 
            
        # 7:when 'E' or 'N' comes in the end of coordinate with ° & ' & " symbols..
        #   we can convert dms 'Degrees,Minutes,Seconds' to dd
            elif  ('°' and "\'" and '\"' and 'N' in coordinate) or ('°' and "\'" and '\"' and 'E' in coordinate):
                degrees, minutes, seconds, direction = re.split('[°\'"]+', coordinate)
                dd = float(degrees) + float(minutes)/60 + float(seconds)/(60*60);
                return dd
            
        # 7: change the . symbol if it was not in its correct place
            elif  '.' in coordinate:
                for indx , c in enumerate(temp_list):
                    if c == '.' and indx != 2:
                        temp_list.pop(indx)
                        if temp_list[2] != '.':
                            temp_list.insert(2,c)
                return ''.join(temp_list)
            
            elif  '.' not in coordinate:
                temp_list.insert(2,'.')
                return ''.join(temp_list)
            
  # If coordinate is not String means it is a clean float 
        else:
            return coordinate

# %%
dataset_filter = Filter()

# %% [markdown]
# in (1) and (2) Cleanings below.. we are using For Loop wich is not the optimal option! apply() function is the best bit in here. However, we have some errors using this function .. So, we deside to use For Loop instead as a temprory solution to clean our data.

# %%
# (1):'Y GIS Coordinates' Column Cleaning     
for n in range(0,atm.shape[0]):
    atm['Y GIS Coordinates'].iloc[n] = dataset_filter.clean_x_y_coordinates(atm['Y GIS Coordinates'].iloc[n])
# Out:
# 26°18'10.16"N
# 24°39'7.56"N
# 24°39'7.56"N
# 24°41'10.09"N
# 24°39'7.56"N
# 24°39'7.56"N
# 24°41'10.09"N
# 29°57'14.06"N
# 26°17'15.39"N
# 24°43'53.65"N
# 24°57'29.53"N
# 24°43'53.65"N
# 27°00'26.0"N
# 19°8'37.61"N
# 18°9'46.13"N
# 18°5'6.63"N
# 21°14'59.30"N
# 29°37'32.82"N
# 18°14'42.49"N
# 18°35'7.87"N
# 18°12'23.60"N
# 24°35'13.59"N
# 24°48'38.8"N
# 21°23.401'N
# 24°27.734'N
# 24°50.494'N
# 21°29.381'N
# 18°5'1.30"N
# 22°12.263'N
# 21°45.600'N

# %%
# (2):'X GIS Coordinates' Column Cleaning    
for n in range(0,atm.shape[0]):
    atm['X GIS Coordinates'].iloc[n] = dataset_filter.clean_x_y_coordinates(atm['X GIS Coordinates'].iloc[n])
# Out:
# 50°10'23.41"E
# 46°47'36.12"E
# 46°47'36.12"E
# 46°44'47.62"E
# 46°47'36.12"E
# 46°47'36.12"E
# 46°44'47.62"E
# 40°11'30.85"E
# 50°12'36.02"E
# 46°40'28.32"E
# 46°42'2.80"E
# 46°40'28.32"E
# 49°39'40.0"E
# 41°4'54.43"E
# 42°50'17.99"E
# 43°8'25.76"E
# 40°24'46.65"E
# 43°30'27.28"E
# 42°46'3.32"E
# 42°41'49.00"E
# 42°49'48.59"E
# 46°32'5.60"E
# 46°44'36.5"E
# 39°42.326'E
# 39°32.005'E
# 46°47.397'E
# 39°13.472'E
# 43°8'37.02"E
# 39°6.969'E
# 39°4.836'E

# %%
#Now, let's test the dataset
atm
# Out:
#                            Site                                   الموقع   \
# 0         CA-AKIK BRANCH BAHA 2                      فرع العقيق الباحة  2
# 1         CA-AKIK BRANCH BAHA 1                       فرع العقيق الباحة 1
# 2            AKIK BRANCH BAHA 3                      فرع العقيق الباحة  3
# 3           AL-WAFA GAS STATION                      محطة الوفاء - العقيق
# 4      ALTAYAR GAS STATION KARA                    محطة الطيار - مركز كرا
# 5             BIN TESHAN CENTER                                  بن طيشان
# 6                    ROYAL MALL                            صراف رويال مول
# 7              CA-ALBAHA BRANCH                              فرع الباحة 1
# 8                 ALBAHA BRANCH                              فرع الباحة 2
# 9           CA-AL ZAWEYA BRANCH                               فرع الزاوية
# 10                RAHWAT AL BAR                           فرع رهوة البر 1
# 11        CA-RAHWAT AL-BAR BR 2                           فرع رهوة البر 2
# 12           AL BAHA REMITTANCE                           حوالات الباحة 1
# 13           CA-BAHA REMITTANCE                          حوالات الباحة 2
# 14           FAISALIYAH STATION                             محطة الفيصلية
# 15            AL AREESH STATION                               محطة العريش
# 16       AL NASRIYA GAS STATION                   محطة الناصرية - بنى سار
# 17         AL SAWAD GAS STATION                               محطة السواد
# 18           NAKHLA GAS STATION                        محطة النخلة/الباحة
# 19         ALHAMMED GAS STATION       محطة الحامد/الباحة ( السلام حاليا )
# 20            BALADIYAT AL-BAHA                              بلدية الباحة
# 21         AL MAGEB GAS STATION                   محطة المعجب / رهوة البر
# 22             AL SAYARI CENTER                              مجمع السيارى
# 23      AL-SHEHAIBI GAS STATION                              محطة الشهيبي
# 24        AL MAFRAK GAS STATION                               محطة المفرق
# 25          ABU AL-KHAIR MARKET                             سوق ابو الخير
# 26      ALALA ALWATANIA COMPANY                          محطة شركة الالاء
# 27                CA-MANDAQ BR.                              فرع المندق 2
# 28             AL-MANDEK BRANCH                              فرع المندق 1
# 29                     ANTEESAR  محطة الانتصار ( الفاران حاليا بالجوفاء )
# ...                         ...                                       ...
# 15749                       NaN                        محطة زيتي - الرمال
# 15750                       NaN             المعهد التقني لخدمات البترول
# 15751                       NaN                     محطة سلطان المالكي(2)
# 15752                       NaN                   مبنى عبدالرحمن المديني
# 15753                       NaN                      مجمع الموج للاتصالات
# 15754                       NaN                            مجمع توب كويزن
# 15755                       NaN                          محطة ظافر الشهري
# 15756                       NaN                     محطة الجزيرة(السحيلي)
# 15757                       NaN            محطة سلطان المالكي(الراية نفط)
# 15758                       NaN              جامعة الحدود الشمالية (غرفة)
# 15759                       NaN                   أرض سلمان محمد القحطاني
# 15760                       NaN                            محطة ديراب (1)
# 15761                       NaN                            محطة ديراب (2)
# 15762                       NaN                     أرض حسن صالح القحطاني
# 15763                       NaN                         مجمع داون الخزامى
# 15764                       NaN                مجمع مؤسسة ازدهار السعودية
# 15765                       NaN                        معارض متعب بن قويد
# 15766                       NaN                         محطة دخيل الرحيلي
# 15767                       NaN                     جامعة الحدود الشمالية
# 15768                       NaN                            فرع الشفاء 440
# 15769                       NaN                 عقار ورثة شامي محمد عسيري
# 15770                       NaN                               محطة الدوحة
# 15771                       NaN                               فندق المشرق
# 15772                       NaN                      مجمع عبدالله بن عون
# 15773                       NaN                    محطة عبدالرحمن العوفان
# 15774                       NaN                          مجمع مشعل المهنا
# 15775                       NaN                      شركة الضاحية الشرقية
# 15776                       NaN              المسجد النبوي (شارع  بن زيد)
# 15777                       NaN                         مجمع مارينا سكوير
# 15778                       NaN            المسجد النبوي (طريق الملك فهد)
#
#         City English      City Arabic      Reg                Brn  \
# 0      AL-AQIQ- BAHA  العقيق - الباحة  AL-BAHA                Brn
# 1      AL-AQIQ- BAHA  العقيق - الباحة  AL-BAHA                Brn
# 2      AL-AQIQ- BAHA  العقيق - الباحة  AL-BAHA                Brn
# 3      AL-AQIQ- BAHA  العقيق - الباحة  AL-BAHA            Of Site
# 4      AL-AQIQ- BAHA  العقيق - الباحة  AL-BAHA            Of Site
# 5      AL-AQIQ- BAHA  العقيق - الباحة  AL-BAHA            Of Site
# 6      AL-AQIQ- BAHA  العقيق - الباحة  AL-BAHA            Of Site
# 7            AL-BAHA           الباحة  AL-BAHA                Brn
# 8            AL-BAHA           الباحة  AL-BAHA                Brn
# 9            AL-BAHA           الباحة  AL-BAHA                Brn
# 10           AL-BAHA           الباحة  AL-BAHA                Brn
# 11           AL-BAHA           الباحة  AL-BAHA                Brn
# 12           AL-BAHA           الباحة  AL-BAHA  Remittance Center
# 13           AL-BAHA           الباحة  AL-BAHA  Remittance Center
# 14           AL-BAHA           الباحة  AL-BAHA            Of Site
# 15           AL-BAHA           الباحة  AL-BAHA            Of Site
# 16           AL-BAHA           الباحة  AL-BAHA            Of Site
# 17           AL-BAHA           الباحة  AL-BAHA            Of Site
# 18           AL-BAHA           الباحة  AL-BAHA            Of Site
# 19           AL-BAHA           الباحة  AL-BAHA            Of Site
# 20           AL-BAHA           الباحة  AL-BAHA            Of Site
# 21           AL-BAHA           الباحة  AL-BAHA            Of Site
# 22           AL-BAHA           الباحة  AL-BAHA            Of Site
# 23           AL-BAHA           الباحة  AL-BAHA            Of Site
# 24           AL-BAHA           الباحة  AL-BAHA            Of Site
# 25           AL-BAHA           الباحة  AL-BAHA            Of Site
# 26           AL-BAHA           الباحة  AL-BAHA            Of Site
# 27         AL-MANDIQ           المندق  AL-BAHA                Brn
# 28         AL-MANDIQ           المندق  AL-BAHA                Brn
# 29         AL-MANDIQ           المندق  AL-BAHA            Of Site
# ...              ...              ...      ...                ...
# 15749            NaN           الرياض      NaN                NaN
# 15750            NaN           الخفجي      NaN                NaN
# 15751            NaN      مكة المكرمة      NaN                NaN
# 15752            NaN             طريف      NaN                NaN
# 15753            NaN           الطائف      NaN                NaN
# 15754            NaN              جدة      NaN                NaN
# 15755            NaN         المجاردة      NaN                NaN
# 15756            NaN              جدة      NaN                NaN
# 15757            NaN      مكة المكرمة      NaN                NaN
# 15758            NaN             عرعر      NaN                NaN
# 15759            NaN            صامطة      NaN                NaN
# 15760            NaN           الرياض      NaN                NaN
# 15761            NaN           الرياض      NaN                NaN
# 15762            NaN             صبيا      NaN                NaN
# 15763            NaN            الخبر      NaN                NaN
# 15764            NaN           الحوطة      NaN                NaN
# 15765            NaN      وادي الدوسر      NaN                NaN
# 15766            NaN  المدينة المنورة      NaN                NaN
# 15767            NaN             عرعر      NaN                NaN
# 15768            NaN           الرياض      NaN                NaN
# 15769            NaN       محايل عسير      NaN                NaN
# 15770            NaN          الظهران      NaN                NaN
# 15771            NaN           الرياض      NaN                NaN
# 15772            NaN              جدة      NaN                NaN
# 15773            NaN             حائل      NaN                NaN
# 15774            NaN             حائل      NaN                NaN
# 15775            NaN           الدمام      NaN                NaN
# 15776            NaN  المدينة المنورة      NaN                NaN
# 15777            NaN              جدة      NaN                NaN
# 15778            NaN  المدينة المنورة      NaN                NaN
#
#                Site Type X GIS Coordinates Y GIS Coordinates
# 0            Room-Window           41.6538           20.2704
# 1            Room-Window           41.6538           20.2704
# 2            Room-Window           41.6538           20.2704
# 3      drive up - Island           41.6327           20.2356
# 4      drive up - Island           41.5977           20.3888
# 5            Room-Window           41.2853           20.1628
# 6      drive up - Island           41.6385           20.2421
# 7             Room-Lobby           41.4695           20.0147
# 8             Room-Lobby           41.4695           20.0147
# 9             Room-Lobby           41.5523           19.9395
# 10            Room-Lobby           41.4479           20.0647
# 11            Room-Lobby           41.4479           20.0647
# 12            Room-Lobby            41.465           20.0102
# 13            Room-Lobby            41.465           20.0102
# 14     drive up - Island           41.4342            20.061
# 15     drive up - Island           41.4436           20.1034
# 16     drive up - Island           41.4464           20.0812
# 17     drive up - Island            41.477           20.0279
# 18     drive up - Island           41.4481           20.0579
# 19     drive up - Island           41.4689           20.0124
# 20     drive up - Island           41.4622           20.0119
# 21     drive up - Island           41.4421           20.0909
# 22     drive up - Island           41.5034           20.0069
# 23     drive up - Island           41.4208           20.1279
# 24     drive up - Island           41.5201           19.9884
# 25           Room-Window           41.4686           20.0181
# 26     drive up - Island           41.5803           20.0905
# 27            Room-Lobby           41.2842           20.1595
# 28            Room-Lobby           41.2842           20.1595
# 29     drive up - Island           41.3479           20.0669
# ...                  ...               ...               ...
# 15749                NaN           46.7899           24.8416
# 15750                NaN            48.448           28.3729
# 15751                NaN           39.8996           21.3614
# 15752                NaN           38.6773           31.6774
# 15753                NaN         40.427764         21.265183
# 15754                NaN           39.2245           21.4897
# 15755                NaN           43.1333           18.0833
# 15756                NaN           39.1161           22.2044
# 15757                NaN           39.8996           21.3614
# 15758                NaN           41.1995           30.8544
# 15759                NaN           42.9217            16.788
# 15760                NaN           46.6096           24.4646
# 15761                NaN           46.6096           24.4646
# 15762                NaN           42.6099           17.2728
# 15763                NaN           50.1957           26.2023
# 15764                NaN            46.878           23.4849
# 15765                NaN           44.8295           20.4552
# 15766                NaN         39.517403         24.489301
# 15767                NaN           41.1995           30.8544
# 15768                NaN           46.7031           24.5575
# 15769                NaN         42.066004         18.544445
# 15770                NaN           50.1611           26.3323
# 15771                NaN           46.6551           24.7045
# 15772                NaN           39.2482           21.5646
# 15773                NaN           41.6576           27.4658
# 15774                NaN           41.6754            27.519
# 15775                NaN           49.9969           26.4197
# 15776                NaN         39.611405         24.471235
# 15777                NaN           39.0806             21.76
# 15778                NaN         39.611405         24.471235
#
# [15779 rows x 9 columns]
